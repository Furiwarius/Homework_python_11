# %% [markdown]
# Дана функция f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# 1. Определить корни
#
# 2. Найти интервалы, на которых функция возрастает
#
# 3. Найти интервалы, на которых функция убывает
#
# 4. Построить график
#
# 5. Вычислить вершину
#
# 6. Определить промежутки, на котором f > 0
#
# 7. Определить промежутки, на котором f < 0

# %%
from sympy import *
from sympy.plotting import plot as plt
# from sympy import Symbol
init_printing()

x = Symbol('x')
fx = -12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30

# %% [markdown]
# 4. Построить график

# %%
p = plt(fx, (x,-100,100))

# %% [markdown]
# 5. Вычислить вершину

# %%
print(solve(diff(fx)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [62], line 1
# ----> 1 solve(diff(fx))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:1112, in solve(f, *symbols, **flags)
#    1108 #
#    1109 # try to get a solution
#    1110 ###########################################################################
#    1111 if bare_f:
# -> 1112     solution = _solve(f[0], *symbols, **flags)
#    1113 else:
#    1114     solution = _solve_system(f, symbols, **flags)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:1580, in _solve(f, *symbols, **flags)
#    1576     if newf != f_num:
#    1577         # don't check the rewritten form --check
#    1578         # solutions in the un-rewritten form below
#    1579         flags['check'] = False
# -> 1580         result = _solve(newf, symbol, **flags)
#    1581         flags['check'] = check
#    1583 # just a simple case - see if replacement of single function
#    1584 # clears all symbol-dependent functions, e.g.
#    1585 # log(x) - log(log(x) - 1) - 3 can be solved even though it has
#    1586 # two generators.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:1580, in _solve(f, *symbols, **flags)
#    1576     if newf != f_num:
#    1577         # don't check the rewritten form --check
#    1578         # solutions in the un-rewritten form below
#    1579         flags['check'] = False
# -> 1580         result = _solve(newf, symbol, **flags)
#    1581         flags['check'] = check
#    1583 # just a simple case - see if replacement of single function
#    1584 # clears all symbol-dependent functions, e.g.
#    1585 # log(x) - log(log(x) - 1) - 3 can be solved even though it has
#    1586 # two generators.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:1736, in _solve(f, *symbols, **flags)
#    1734 flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1735 try:
# -> 1736     soln = _tsolve(f_num, symbol, **flags)
#    1737     if soln is not None:
#    1738         result = soln
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:2587, in _tsolve(eq, sym, **flags)
#    2585 f = factor(powdenest(lhs - rhs))
#    2586 if f.is_Mul:
# -> 2587     return _solve(f, sym, **flags)
#    2588 if rhs:
#    2589     f = logcombine(lhs, force=flags.get('force', True))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:1418, in _solve(f, *symbols, **flags)
#    1416         result = set()
#    1417         break
# -> 1418     soln = _solve(m, symbol, **flags)
#    1419     result.update(set(soln))
#    1420 result = list(result)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:1736, in _solve(f, *symbols, **flags)
#    1734 flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1735 try:
# -> 1736     soln = _tsolve(f_num, symbol, **flags)
#    1737     if soln is not None:
#    1738         result = soln
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:2706, in _tsolve(eq, sym, **flags)
#    2704     rewrite = lhs.rewrite(exp)
#    2705     if rewrite != lhs:
# -> 2706         return _solve(rewrite - rhs, sym, **flags)
#    2707 except NotImplementedError:
#    2708     pass
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:1736, in _solve(f, *symbols, **flags)
#    1734 flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1735 try:
# -> 1736     soln = _tsolve(f_num, symbol, **flags)
#    1737     if soln is not None:
#    1738         result = soln
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:2585, in _tsolve(eq, sym, **flags)
#    2581 try:
#    2582     if lhs.is_Add:
#    2583         # it's time to try factoring; powdenest is used
#    2584         # to try get powers in standard form for better factoring
# -> 2585         f = factor(powdenest(lhs - rhs))
#    2586         if f.is_Mul:
#    2587             return _solve(f, sym, **flags)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:6449, in factor(f, deep, *gens, **args)
#    6446     return f.xreplace(partials)
#    6448 try:
# -> 6449     return _generic_factor(f, gens, args, method='factor')
#    6450 except PolynomialError as msg:
#    6451     if not f.is_commutative:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:6130, in _generic_factor(expr, gens, args, method)
#    6128 opt = options.build_options(gens, args)
#    6129 opt['fraction'] = fraction
# -> 6130 return _symbolic_factor(sympify(expr), opt, method)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:6070, in _symbolic_factor(expr, opt, method)
#    6068     if hasattr(expr,'_eval_factor'):
#    6069         return expr._eval_factor()
# -> 6070     coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    6071     return _keep_coeff(coeff, _factors_product(factors))
#    6072 elif hasattr(expr, 'args'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:6035, in _symbolic_factor_list(expr, opt, method)
#    6032 else:
#    6033     func = getattr(poly, method + '_list')
# -> 6035     _coeff, _factors = func()
#    6036     if _coeff is not S.One:
#    6037         if exp.is_Integer:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:3350, in Poly.factor_list(f)
#    3348 if hasattr(f.rep, 'factor_list'):
#    3349     try:
# -> 3350         coeff, factors = f.rep.factor_list()
#    3351     except DomainError:
#    3352         return S.One, [(f, 1)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyclasses.py:823, in DMP.factor_list(f)
#     821 def factor_list(f):
#     822     """Returns a list of irreducible factors of ``f``. """
# --> 823     coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#     824     return coeff, [ (f.per(g), k) for g, k in factors ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\factortools.py:1403, in dmp_factor_list(f, u, K0)
#    1401     coeff, factors = dmp_ext_factor(f, u, K0)
#    1402 elif K0.is_GaussianRing:
# -> 1403     coeff, factors = dmp_zz_i_factor(f, u, K0)
#    1404 elif K0.is_GaussianField:
#    1405     coeff, factors = dmp_qq_i_factor(f, u, K0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\factortools.py:1218, in dmp_zz_i_factor(f, u, K0)
#    1216 K1 = K0.get_field()
#    1217 f = dmp_convert(f, u, K0, K1)
# -> 1218 coeff, factors = dmp_qq_i_factor(f, u, K1)
#    1220 new_factors = []
#    1221 for fac, i in factors:
#    1222     # Extract content
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\factortools.py:1207, in dmp_qq_i_factor(f, u, K0)
#    1205 K1 = K0.as_AlgebraicField()
#    1206 f = dmp_convert(f, u, K0, K1)
# -> 1207 coeff, factors = dmp_factor_list(f, u, K1)
#    1208 factors = [(dmp_convert(fac, u, K1, K0), i) for fac, i in factors]
#    1209 coeff = K0.convert(coeff, K1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\factortools.py:1401, in dmp_factor_list(f, u, K0)
#    1399     coeff, factors = dmp_gf_factor(f, u, K0)
#    1400 elif K0.is_Algebraic:
# -> 1401     coeff, factors = dmp_ext_factor(f, u, K0)
#    1402 elif K0.is_GaussianRing:
#    1403     coeff, factors = dmp_zz_i_factor(f, u, K0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\factortools.py:1277, in dmp_ext_factor(f, u, K)
#    1274 if all(d <= 0 for d in dmp_degree_list(f, u)):
#    1275     return lc, []
# -> 1277 f, F = dmp_sqf_part(f, u, K), f
#    1278 s, g, r = dmp_sqf_norm(f, u, K)
#    1280 factors = dmp_factor_list_include(r, u, K.dom)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\sqfreetools.py:256, in dmp_sqf_part(f, u, K)
#     254 gcd = f
#     255 for i in range(u+1):
# --> 256     gcd = dmp_gcd(gcd, dmp_diff_in(f, 1, i, u, K), u, K)
#     257 sqf = dmp_quo(f, gcd, u, K)
#     259 if K.is_Field:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\euclidtools.py:1625, in dmp_gcd(f, g, u, K)
#    1608 def dmp_gcd(f, g, u, K):
#    1609     """
#    1610     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1611
#    (...)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\euclidtools.py:1549, in _dmp_inner_gcd(f, g, u, K)
#    1546         except HeuristicGCDFailed:
#    1547             pass
# -> 1549     return dmp_ff_prs_gcd(f, g, u, K)
#    1550 else:
#    1551     if K.is_ZZ and query('USE_HEU_GCD'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\euclidtools.py:1114, in dmp_ff_prs_gcd(f, g, u, K)
#    1111 fc, F = dmp_primitive(f, u, K)
#    1112 gc, G = dmp_primitive(g, u, K)
# -> 1114 h = dmp_subresultants(F, G, u, K)[-1]
#    1115 c, _, _ = dmp_ff_prs_gcd(fc, gc, u - 1, K)
#    1117 _, h = dmp_primitive(h, u, K)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\euclidtools.py:549, in dmp_subresultants(f, g, u, K)
#     529 def dmp_subresultants(f, g, u, K):
#     530     """
#     531     Computes subresultant PRS of two polynomials in `K[X]`.
#     532
#    (...)
#     547
#     548     """
# --> 549     return dmp_inner_subresultants(f, g, u, K)[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\euclidtools.py:512, in dmp_inner_subresultants(f, g, u, K)
#     507 f, g, m, d = g, h, k, m - k
#     509 b = dmp_mul(dmp_neg(lc, v, K),
#     510             dmp_pow(c, d, v, K), v, K)
# --> 512 h = dmp_prem(f, g, u, K)
#     513 h = [ dmp_quo(ch, b, v, K) for ch in h ]
#     515 lc = dmp_LC(g, K)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\densearith.py:1237, in dmp_prem(f, g, u, K)
#    1234 lc_r = dmp_LC(r, K)
#    1235 j, N = dr - dg, N - 1
# -> 1237 R = dmp_mul_term(r, lc_g, 0, u, K)
#    1238 G = dmp_mul_term(g, lc_r, j, u, K)
#    1239 r = dmp_sub(R, G, u, K)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\densearith.py:184, in dmp_mul_term(f, c, i, u, K)
#     182     return dmp_zero(u)
#     183 else:
# --> 184     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\densearith.py:184, in <listcomp>(.0)
#     182     return dmp_zero(u)
#     183 else:
# --> 184     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
#     [... skipping similar frames: dmp_mul at line 828 (4 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\densearith.py:567, in dmp_add(f, g, u, K)
#     563     return dup_add(f, g, K)
#     565 df = dmp_degree(f, u)
# --> 567 if df < 0:
#     568     return g
#     570 dg = dmp_degree(g, u)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\decorators.py:236, in _SympifyWrapper.make_wrapped.<locals>._func(self, other)
#     234 if not isinstance(other, expectedcls):
#     235     return retval
# --> 236 return func(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\expr.py:376, in Expr.__lt__(self, other)
#     373 @sympify_return([('other', 'Expr')], NotImplemented)
#     374 def __lt__(self, other):
#     375     from .relational import StrictLessThan
# --> 376     return StrictLessThan(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\relational.py:845, in _Inequality.__new__(cls, lhs, rhs, **options)
#     836             raise TypeError("Invalid NaN comparison")
#     837     # First we invoke the appropriate inequality method of `lhs`
#     838     # (e.g., `lhs.__lt__`).  That method will try to reduce to
#     839     # boolean or raise an exception.  It may keep calling
#    (...)
#     843     # exception).  In that case, it must call us with
#     844     # `evaluate=False` to prevent infinite recursion.
# --> 845     return cls._eval_relation(lhs, rhs, **options)
#     847 # make a "non-evaluated" Expr for the inequality
#     848 return Relational.__new__(cls, lhs, rhs, **options)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\relational.py:852, in _Inequality._eval_relation(cls, lhs, rhs, **options)
#     850 @classmethod
#     851 def _eval_relation(cls, lhs, rhs, **options):
# --> 852     val = cls._eval_fuzzy_relation(lhs, rhs)
#     853     if val is None:
#     854         return cls(lhs, rhs, evaluate=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\relational.py:1179, in StrictLessThan._eval_fuzzy_relation(cls, lhs, rhs)
#    1177 @classmethod
#    1178 def _eval_fuzzy_relation(cls, lhs, rhs):
# -> 1179     return is_lt(lhs, rhs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\relational.py:1258, in is_lt(lhs, rhs, assumptions)
#    1253 def is_lt(lhs, rhs, assumptions=None):
#    1254     """Fuzzy bool for lhs is strictly less than rhs.
#    1255
#    1256     See the docstring for :func:`~.is_ge` for more.
#    1257     """
# -> 1258     return fuzzy_not(is_ge(lhs, rhs, assumptions))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\relational.py:1380, in is_ge(lhs, rhs, assumptions)
#    1378     return retval
#    1379 else:
# -> 1380     n2 = _n2(lhs, rhs)
#    1381     if n2 is not None:
#    1382         # use float comparison for infinity.
#    1383         # otherwise get stuck in infinite recursion
#    1384         if n2 in (S.Infinity, S.NegativeInfinity):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\relational.py:1215, in _n2(a, b)
#    1212 # /!\ it is very important (see issue 8245) not to
#    1213 # use a re-evaluated number in the calculation of dif
#    1214 if a.is_comparable and b.is_comparable:
# -> 1215     dif = (a - b).evalf(2)
#    1216     if dif.is_comparable:
#    1217         return dif
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\decorators.py:65, in __sympifyit.<locals>.__sympifyit_wrapper(a, b)
#      63     if not hasattr(b, '_op_priority'):
#      64         b = sympify(b, strict=True)
# ---> 65     return func(a, b)
#      66 except SympifyError:
#      67     return retval
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\numbers.py:3496, in NegativeInfinity.__sub__(self, other)
#    3493 @_sympifyit('other', NotImplemented)
#    3494 def __sub__(self, other):
#    3495     if isinstance(other, Number) and global_parameters.evaluate:
# -> 3496         if other in (S.NegativeInfinity, S.NaN):
#    3497             return S.NaN
#    3498         return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\numbers.py:3584, in NegativeInfinity.__eq__(self, other)
#    3583 def __eq__(self, other):
# -> 3584     return other is S.NegativeInfinity or other == float('-inf')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\numbers.py:2243, in Integer.__eq__(self, other)
#    2241 elif isinstance(other, Integer):
#    2242     return (self.p == other.p)
# -> 2243 return Rational.__eq__(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\numbers.py:1869, in Rational.__eq__(self, other)
#    1867 def __eq__(self, other):
#    1868     try:
# -> 1869         other = _sympify(other)
#    1870     except SympifyError:
#    1871         return NotImplemented
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\sympify.py:529, in _sympify(a)
#     503 def _sympify(a):
#     504     """
#     505     Short version of :func:`~.sympify` for internal usage for ``__add__`` and
#     506     ``__eq__`` methods where it is ok to allow some things (like Python
#    (...)
#     527
#     528     """
# --> 529     return sympify(a, strict=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\sympify.py:371, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     368     else:
#     369         raise SympifyError(a)
# --> 371 if isinstance(a, CantSympify):
#     372     raise SympifyError(a)
#     374 cls = getattr(a, "__class__", None)
#
# KeyboardInterrupt:

# %% [markdown]
# 6. Определить промежутки, на котором f > 0

# %%
print(solve(fx>0))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:211, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     209         base, exp = decompose_power_rat(factor)
# --> 211     monom[indices[base]] = exp
#     212 except KeyError:
#
# KeyError: sin(cos(_x))
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:809, in _solve_inequality(ie, s, linear)
#     808 try:
# --> 809     p = Poly(expr, s)
#     810     if p.degree() == 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:311, in Poly._from_expr(cls, rep, opt)
#     310 """Construct a polynomial from an expression. """
# --> 311 rep, opt = _dict_from_expr(rep, opt)
#     312 return cls._from_dict(rep, opt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:368, in _dict_from_expr(expr, opt)
#     367 if opt.gens:
# --> 368     rep, gens = _dict_from_expr_if_gens(expr, opt)
#     369 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:307, in _dict_from_expr_if_gens(expr, opt)
#     306 """Transform an expression into a multinomial form given generators. """
# --> 307 (poly,), gens = _parallel_dict_from_expr_if_gens((expr,), opt)
#     308 return poly, gens
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:216, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     215             else:
# --> 216                 raise PolynomialError("%s contains an element of "
#     217                                       "the set of generators." % factor)
#     219 monom = tuple(monom)
#
# PolynomialError: sin(cos(_x)) contains an element of the set of generators.
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:211, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     209         base, exp = decompose_power_rat(factor)
# --> 211     monom[indices[base]] = exp
#     212 except KeyError:
#
# KeyError: sin(cos(_x))
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:247, in reduce_rational_inequalities(exprs, gen, relational)
#     246 try:
# --> 247     (numer, denom), opt = parallel_poly_from_expr(
#     248         (numer, denom), gen)
#     249 except PolynomialError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:4411, in parallel_poly_from_expr(exprs, *gens, **args)
#    4410 opt = options.build_options(gens, args)
# -> 4411 return _parallel_poly_from_expr(exprs, opt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:4462, in _parallel_poly_from_expr(exprs, opt)
#    4460         exprs[i] = exprs[i].as_expr()
# -> 4462 reps, opt = _parallel_dict_from_expr(exprs, opt)
#    4463 if not opt.gens:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:332, in _parallel_dict_from_expr(exprs, opt)
#     331 if opt.gens:
# --> 332     reps, gens = _parallel_dict_from_expr_if_gens(exprs, opt)
#     333 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:216, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     215             else:
# --> 216                 raise PolynomialError("%s contains an element of "
#     217                                       "the set of generators." % factor)
#     219 monom = tuple(monom)
#
# PolynomialError: sin(cos(_x)) contains an element of the set of generators.
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:818, in _solve_inequality(ie, s, linear)
#     817 try:
# --> 818     rv = reduce_rational_inequalities([[ie]], s)
#     819 except PolynomialError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:250, in reduce_rational_inequalities(exprs, gen, relational)
#     249 except PolynomialError:
# --> 250     raise PolynomialError(filldedent('''
#     251         only polynomials and rational functions are
#     252         supported in this context.
#     253         '''))
#     255 if not opt.domain.is_Exact:
#
# PolynomialError:
# only polynomials and rational functions are supported in this context.
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:518, in solve_univariate_inequality(expr, gen, relational, domain, continuous)
#     516 # this might raise ValueError on its own
#     517 # or it might give None...
# --> 518 solns = solvify(e, gen, domain)
#     519 if solns is None:
#     520     # in which case we raise ValueError
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solveset.py:2370, in solvify(f, symbol, domain)
#    2369 elif isinstance(solution_set, ConditionSet):
# -> 2370     raise NotImplementedError('solveset is unable to solve this equation.')
#    2372 elif isinstance(solution_set, FiniteSet):
#
# NotImplementedError: solveset is unable to solve this equation.
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# Cell In [58], line 1
# ----> 1 print(solve(fx>0))
#       2 # solve(fx>0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:928, in solve(f, *symbols, **flags)
#     925     f[i] = fi
#     927 if fi.is_Relational:
# --> 928     return reduce_inequalities(f, symbols=symbols)
#     930 if isinstance(fi, Poly):
#     931     f[i] = fi.as_expr()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:981, in reduce_inequalities(inequalities, symbols)
#     978 del keep
#     980 # solve system
# --> 981 rv = _reduce_inequalities(inequalities, symbols)
#     983 # restore original symbols and return
#     984 return rv.xreplace({v: k for k, v in recast.items()})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:919, in _reduce_inequalities(inequalities, symbols)
#     917             abs_part.setdefault(gen, []).append((expr, rel))
#     918         else:
# --> 919             other.append(_solve_inequality(Relational(expr, 0, rel), gen))
#     921 poly_reduced = [reduce_rational_inequalities([exprs], gen) for gen, exprs in poly_part.items()]
#     922 abs_reduced = [reduce_abs_inequalities(exprs, gen) for gen, exprs in abs_part.items()]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:820, in _solve_inequality(ie, s, linear)
#     818     rv = reduce_rational_inequalities([[ie]], s)
#     819 except PolynomialError:
# --> 820     rv = solve_univariate_inequality(ie, s)
#     821 # remove restrictions wrt +/-oo that may have been
#     822 # applied when using sets to simplify the relationship
#     823 okoo = classify(ie, s, oo)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:525, in solve_univariate_inequality(expr, gen, relational, domain, continuous)
#     521         raise ValueError
#     522 except (ValueError, NotImplementedError):
#     523     # replace gen with generic x since it's
#     524     # univariate anyway
# --> 525     raise NotImplementedError(filldedent('''
#     526         The inequality, %s, cannot be solved using
#     527         solve_univariate_inequality.
#     528         ''' % expr.subs(gen, Symbol('x'))))
#     530 expanded_e = expand_mul(e)
#     531 def valid(x):
#     532     # this is used to see if gen=x satisfies the
#     533     # relational by substituting it into the
#    (...)
#     539     #
#     540     # expanded_e, expr and gen used from enclosing scope
#
# NotImplementedError:
# The inequality, -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30 >
# 0, cannot be solved using solve_univariate_inequality.

# %% [markdown]
# 7. Определить промежутки, на котором f < 0

# %%
print(solve(fx<0))
# solve(fx<0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:211, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     209         base, exp = decompose_power_rat(factor)
# --> 211     monom[indices[base]] = exp
#     212 except KeyError:
#
# KeyError: sin(cos(_x))
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:809, in _solve_inequality(ie, s, linear)
#     808 try:
# --> 809     p = Poly(expr, s)
#     810     if p.degree() == 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:182, in Poly.__new__(cls, rep, *gens, **args)
#     181 else:
# --> 182     return cls._from_expr(rep, opt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:311, in Poly._from_expr(cls, rep, opt)
#     310 """Construct a polynomial from an expression. """
# --> 311 rep, opt = _dict_from_expr(rep, opt)
#     312 return cls._from_dict(rep, opt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:368, in _dict_from_expr(expr, opt)
#     367 if opt.gens:
# --> 368     rep, gens = _dict_from_expr_if_gens(expr, opt)
#     369 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:307, in _dict_from_expr_if_gens(expr, opt)
#     306 """Transform an expression into a multinomial form given generators. """
# --> 307 (poly,), gens = _parallel_dict_from_expr_if_gens((expr,), opt)
#     308 return poly, gens
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:216, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     215             else:
# --> 216                 raise PolynomialError("%s contains an element of "
#     217                                       "the set of generators." % factor)
#     219 monom = tuple(monom)
#
# PolynomialError: sin(cos(_x)) contains an element of the set of generators.
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:211, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     209         base, exp = decompose_power_rat(factor)
# --> 211     monom[indices[base]] = exp
#     212 except KeyError:
#
# KeyError: sin(cos(_x))
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:247, in reduce_rational_inequalities(exprs, gen, relational)
#     246 try:
# --> 247     (numer, denom), opt = parallel_poly_from_expr(
#     248         (numer, denom), gen)
#     249 except PolynomialError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:4411, in parallel_poly_from_expr(exprs, *gens, **args)
#    4410 opt = options.build_options(gens, args)
# -> 4411 return _parallel_poly_from_expr(exprs, opt)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py:4462, in _parallel_poly_from_expr(exprs, opt)
#    4460         exprs[i] = exprs[i].as_expr()
# -> 4462 reps, opt = _parallel_dict_from_expr(exprs, opt)
#    4463 if not opt.gens:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:332, in _parallel_dict_from_expr(exprs, opt)
#     331 if opt.gens:
# --> 332     reps, gens = _parallel_dict_from_expr_if_gens(exprs, opt)
#     333 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polyutils.py:216, in _parallel_dict_from_expr_if_gens(exprs, opt)
#     215             else:
# --> 216                 raise PolynomialError("%s contains an element of "
#     217                                       "the set of generators." % factor)
#     219 monom = tuple(monom)
#
# PolynomialError: sin(cos(_x)) contains an element of the set of generators.
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:818, in _solve_inequality(ie, s, linear)
#     817 try:
# --> 818     rv = reduce_rational_inequalities([[ie]], s)
#     819 except PolynomialError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:250, in reduce_rational_inequalities(exprs, gen, relational)
#     249 except PolynomialError:
# --> 250     raise PolynomialError(filldedent('''
#     251         only polynomials and rational functions are
#     252         supported in this context.
#     253         '''))
#     255 if not opt.domain.is_Exact:
#
# PolynomialError:
# only polynomials and rational functions are supported in this context.
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:518, in solve_univariate_inequality(expr, gen, relational, domain, continuous)
#     516 # this might raise ValueError on its own
#     517 # or it might give None...
# --> 518 solns = solvify(e, gen, domain)
#     519 if solns is None:
#     520     # in which case we raise ValueError
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solveset.py:2370, in solvify(f, symbol, domain)
#    2369 elif isinstance(solution_set, ConditionSet):
# -> 2370     raise NotImplementedError('solveset is unable to solve this equation.')
#    2372 elif isinstance(solution_set, FiniteSet):
#
# NotImplementedError: solveset is unable to solve this equation.
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# Cell In [59], line 1
# ----> 1 print(solve(fx<0))
#       2 # solve(fx<0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:928, in solve(f, *symbols, **flags)
#     925     f[i] = fi
#     927 if fi.is_Relational:
# --> 928     return reduce_inequalities(f, symbols=symbols)
#     930 if isinstance(fi, Poly):
#     931     f[i] = fi.as_expr()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:981, in reduce_inequalities(inequalities, symbols)
#     978 del keep
#     980 # solve system
# --> 981 rv = _reduce_inequalities(inequalities, symbols)
#     983 # restore original symbols and return
#     984 return rv.xreplace({v: k for k, v in recast.items()})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:919, in _reduce_inequalities(inequalities, symbols)
#     917             abs_part.setdefault(gen, []).append((expr, rel))
#     918         else:
# --> 919             other.append(_solve_inequality(Relational(expr, 0, rel), gen))
#     921 poly_reduced = [reduce_rational_inequalities([exprs], gen) for gen, exprs in poly_part.items()]
#     922 abs_reduced = [reduce_abs_inequalities(exprs, gen) for gen, exprs in abs_part.items()]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:820, in _solve_inequality(ie, s, linear)
#     818     rv = reduce_rational_inequalities([[ie]], s)
#     819 except PolynomialError:
# --> 820     rv = solve_univariate_inequality(ie, s)
#     821 # remove restrictions wrt +/-oo that may have been
#     822 # applied when using sets to simplify the relationship
#     823 okoo = classify(ie, s, oo)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\inequalities.py:525, in solve_univariate_inequality(expr, gen, relational, domain, continuous)
#     521         raise ValueError
#     522 except (ValueError, NotImplementedError):
#     523     # replace gen with generic x since it's
#     524     # univariate anyway
# --> 525     raise NotImplementedError(filldedent('''
#     526         The inequality, %s, cannot be solved using
#     527         solve_univariate_inequality.
#     528         ''' % expr.subs(gen, Symbol('x'))))
#     530 expanded_e = expand_mul(e)
#     531 def valid(x):
#     532     # this is used to see if gen=x satisfies the
#     533     # relational by substituting it into the
#    (...)
#     539     #
#     540     # expanded_e, expr and gen used from enclosing scope
#
# NotImplementedError:
# The inequality, -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30 <
# 0, cannot be solved using solve_univariate_inequality.

# %% [markdown]
# 1. Определить корни

# %%
list_x = solve(fx)
for i, elem in enumerate(list_x):
    print(f"{i} корень: {elem}")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 x1, x2 = solve(fx)
#       2 print('первый корень', round(x1.evalf(), 2),'\nвторой корень', round(x2.evalf(), 2))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:1112, in solve(f, *symbols, **flags)
#    1108 #
#    1109 # try to get a solution
#    1110 ###########################################################################
#    1111 if bare_f:
# -> 1112     solution = _solve(f[0], *symbols, **flags)
#    1113 else:
#    1114     solution = _solve_system(f, symbols, **flags)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py:1744, in _solve(f, *symbols, **flags)
#    1741 # ----------- end of fallback ----------------------------
#    1743 if result is False:
# -> 1744     raise NotImplementedError('\n'.join([msg, not_impl_msg % f]))
#    1746 if flags.get('simplify', True):
#    1747     result = list(map(simplify, result))
#
# NotImplementedError: multiple generators [x, sin(cos(x))]
# No algorithms are implemented to solve equation -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %% [markdown]
# 2. Найти интервалы, на которых функция возрастает

# %%
solve(diff(fx)>0)
# Out:
# -∞ < x ∧ x < 1

# %% [markdown]
# 3. Найти интервалы, на которых функция убывает

# %%
solve(diff(fx)<0)
# Out:
# 1 < x ∧ x < ∞
